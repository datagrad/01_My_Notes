# %% [markdown]
# <a href="https://colab.research.google.com/github/datagrad/My_Notes/blob/main/Pandas_20_codes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Certainly, here's a list of the top 20 most commonly used Pandas code snippets for Exploratory Data Analysis (EDA):
#
# **1. Import Pandas:**
#
# ```python
# import pandas as pd
# ```
#
# **2. Load Data:**
#
# ```python
# df = pd.read_csv('data.csv')
# ```
#
# **3. Display First Few Rows:**
#
# ```python
# df.head()
# ```
#
# **4. Display Summary Statistics:**
#
# ```python
# df.describe()
# ```
#
# **5. Check Data Types:**
#
# ```python
# df.dtypes
# ```
#
# **6. Check Missing Values:**
#
# ```python
# df.isnull().sum()
# ```
#
# **7. Drop Columns:**
#
# ```python
# df.drop(['column_name'], axis=1, inplace=True)
# ```
#
# **8. Fill Missing Values:**
#
# ```python
# df['column_name'].fillna(value, inplace=True)
# ```
#
# **9. Filter Rows:**
#
# ```python
# filtered_df = df[df['column_name'] > threshold]
# ```
#
# **10. Groupby and Aggregation:**
#
# ```python
# grouped_df = df.groupby('column_name')['target_column'].agg(['mean', 'sum'])
# ```
#
# **11. Pivot Table:**
#
# ```python
# pivot_table = df.pivot_table(index='index_column', columns='column_name', values='target_column', aggfunc='mean')
# ```
#
# **12. Sorting:**
#
# ```python
# sorted_df = df.sort_values(by='column_name', ascending=False)
# ```
#
# **13. Unique Values:**
#
# ```python
# unique_values = df['column_name'].unique()
# ```
#
# **14. Value Counts:**
#
# ```python
# value_counts = df['column_name'].value_counts()
# ```
#
# **15. Rename Columns:**
#
# ```python
# df.rename(columns={'old_name': 'new_name'}, inplace=True)
# ```
#
# **16. Merge DataFrames:**
#
# ```python
# merged_df = pd.merge(left_df, right_df, on='key_column', how='inner')
# ```
#
# **17. Time Series Operations:**
#
# ```python
# df['date_column'] = pd.to_datetime(df['date_column'])
# df.set_index('date_column', inplace=True)
# ```
#
# **18. Apply Function to Column:**
#
# ```python
# df['new_column'] = df['column_name'].apply(lambda x: custom_function(x))
# ```
#
# **19. Create Dummy Variables:**
#
# ```python
# dummy_df = pd.get_dummies(df['categorical_column'], drop_first=True)
# ```
#
# **20. Plotting:**
#
# ```python
# import matplotlib.pyplot as plt
# import seaborn as sns
#
# sns.scatterplot(x='x_column', y='y_column', data=df)
# plt.show()
# ```
#
# These Pandas code snippets provide you with the foundational tools to perform a wide range of data manipulation, analysis, and visualization tasks during Exploratory Data Analysis.
