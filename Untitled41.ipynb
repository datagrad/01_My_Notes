# %% [markdown]
# <a href="https://colab.research.google.com/github/datagrad/01_My_Notes/blob/main/Untitled41.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Kamal Kumar**
# **Senior Data Analyst (Business Intelligence)**
# 📞 +91 9148101482 | ✉️ databykamal@gmail.com
# 🏠 Bengaluru, India | 🔗 linkedin.com/in/jhakamal/
#
# ---
#
# **SUMMARY**
# Data science professional with over 8 years of experience specializing in Data Analytics, Business Intelligence (BI), and Statistical Modeling. Expert in leading end-to-end data science projects, with a strong focus on SQL programming, data management, and data-driven solutions. Proficient in advanced data visualization, statistical analysis, team management, feature engineering, ETL paradigms, and Python.
#
# ---
#
# **TECHNICAL SKILLS**
# - **Programming Languages**: SQL, Python, Yaml
# - **Data Visualization**: Tableau, PowerBI, Matplotlib, Excel, PowerPoint
# - **Machine Learning**: Statistical Modeling, Time Series Analysis, Time Series Modeling, Anomaly Detection
# - **Soft Skills**: Analytical Problem-Solving, Effective Communication, Leadership, Adaptability, Strategic Insight
#
# ---
#
# **PROFESSIONAL EXPERIENCE**
#
# **Data Analyst II, Oracle Cerner**
# Jun 2020 - Present, Bengaluru
# - Led aftersales data analysis for 400+ clients, improving operational efficiency with real-time abnormality detection.
# - Designed and deployed statistical models for performance monitoring and client performance anomalies.
# - Managed data pipelines for large-scale data collection and analysis, and developed KPI-driven visualizations.
#
# **Technical Consultant, Collins Aerospace**
# Feb 2019 - May 2020, Bengaluru, IN
# - Implemented a Power BI-based client help portal, significantly reducing issue response time.
# - Developed a predictive model for aircraft part maintenance, enhancing scheduling and reducing downtime.
# - Established a real-time tracking dashboard to enhance team efficiency and project management.
#
# **Process Associate, Capgemini**
# Apr 2017 - Feb 2019, Bengaluru
# - Conducted inventory stock analysis for Bombardier Aircrafts, recommending alternatives for unavailable parts.
# - Utilized data analysis for actionable insights into design modifications, parts lifecycle, and counterfeit risks.
#
# **Engineer, Aerodesign Solutions Pvt Ltd**
# Jul 2015 - Mar 2017, Bengaluru
# - Supported aviation market insights for successful project bids and developed bid optimization tools.
# - Enhanced pricing, timelines, and resource allocation strategies using historical data and client feedback.
#
# ---
#
# **EDUCATION**
# Master of Science in Data Science, Liverpool John Moores University
# Post Graduate Diploma in Data Science, IIIT Bangalore
# Bachelor of Technology in Aerospace, Hindustan Aviation Academy
#
# ---
#
# **CERTIFICATIONS**
# - Post Graduate Certification in Data Science, upGrad, January 2022
# - Data Analyst and Business Intelligence Certification, 365 Data Science Business Analyst, May 2021
# - Business Intelligence with SQL and Power BI, Simplilearn, March 2019
#
# ---

# %% [markdown]
# **Kamal Kumar**
# Senior Data Analyst (Business Intelligence)
# 📞 +91 9148101482 | ✉️ databykamal@gmail.com
# 🏠 Bengaluru, India | 🔗 linkedin.com/in/jhakamal/
#
# ---
#
# **SUMMARY**
# Data science professional with over 8 years of experience specializing in Data Analytics, Business Intelligence (BI), and Statistical Modeling. Expert in leading end-to-end data science projects, with a strong focus on SQL programming, data management, and delivering data-driven solutions. Proficient in advanced data visualization, statistical analysis, team management, feature engineering, ETL paradigms, and Python. **Skilled in translating business requirements into technical solutions, enhancing data-driven decision-making processes.**
#
# ---
#
# **TECHNICAL SKILLS**
# - **Programming Languages**: SQL, Python, Yaml
# - **Data Visualization Tools**: Tableau, PowerBI, Matplotlib, Excel, PowerPoint
# - **Machine Learning & Statistical Analysis**: Statistical Modeling, Time Series Analysis, Time Series Modeling, Anomaly Detection
# - **Project Management & Collaboration Tools**: [**Add tools if applicable, e.g., JIRA, Asana**]
# - **Soft Skills**: Analytical Problem-Solving, Effective Communication, Leadership, Adaptability, Strategic Insight
#
# ---
#
# **PROFESSIONAL EXPERIENCE**
#
# **Data Analyst II, Oracle Cerner**
# Jun 2020 - Present, Bengaluru
# - **Improved operational efficiency by 30%** through leading aftersales data analysis for 400+ clients, utilizing real-time abnormality detection.
# - Designed and deployed statistical models for performance monitoring, **reducing downtime by 25% across 400+ clients**.
# - Engineered data pipelines for large-scale data collection and analysis, developing KPI-driven visualizations that **supported strategic business decisions**.
#
# **Technical Consultant, Collins Aerospace**
# Feb 2019 - May 2020, Bengaluru, IN
# - Led the deployment of a Power BI-based client help portal, **cutting issue response time to within 1 day for 68% of cases**, exceeding the 4-day target.
# - Developed a predictive model for aircraft part maintenance, **enhancing scheduling efficiency and reducing downtime by 20%**.
# - Established a real-time tracking dashboard for coordinating 7 teams, **improving project management efficiency by 35%**.
#
# **Process Associate, Capgemini**
# Apr 2017 - Feb 2019, Bengaluru
# - Conducted inventory stock analysis for Bombardier Aircrafts, **identifying and mitigating stock deficiencies**, leading to a **10% reduction in part unavailability**.
# - Provided actionable insights into design modifications and counterfeit risks, **enhancing fleet safety and compliance**.
#
# **Engineer, Aerodesign Solutions Pvt Ltd**
# Jul 2015 - Mar 2017, Bengaluru
# - Developed a bid optimization tool using Excel VBA, **increasing bid efficiency by 40%**.
# - Improved pricing, timelines, and resource allocation strategies, leading to a **15% increase in project profitability**.
#
# ---
#
# **EDUCATION**
# Master of Science in Data Science, Liverpool John Moores University
# Post Graduate Diploma in Data Science, IIIT Bangalore
# Bachelor of Technology in Aerospace, Hindustan Aviation Academy
#
# ---
#
# **CERTIFICATIONS**
# - Post Graduate Certification in Data Science, upGrad, January 2022
# - Data Analyst and Business Intelligence Certification, 365 Data Science Business Analyst, May 2021
# - Business Intelligence with SQL and Power BI, Simplilearn, March 2019
#
# ---

# %% [markdown]
# Given the constraints of this text-based format, I'll indicate modifications with an asterisk (*) and describe the changes, as I can't change the text color or style here. For a final implementation in a document, you could use text formatting (such as bold or a different color) to highlight these changes.
#
# ---
#
# **Kamal Kumar**
# Senior Data Analyst (Business Intelligence)
# 📞 +91 9148101482 | ✉️ databykamal@gmail.com
# 🏠 Bengaluru, India | 🔗 linkedin.com/in/jhakamal/
#
# ---
#
# **SUMMARY**
# Data science professional with over 8 years of experience specializing in Data Analytics, Business Intelligence (BI), and Statistical Modeling. Expert in leading end-to-end data science projects, with a strong focus on SQL programming, data management, and data-driven solutions. Proficient in advanced data visualization, statistical analysis, team management, feature engineering, ETL paradigms, and Python. *Skilled in translating business requirements into technical solutions to drive efficiency and insights.*
#
# ---
#
# **TECHNICAL SKILLS**
# - **Programming Languages**: SQL, Python, Yaml
# - **Data Visualization**: Tableau, PowerBI, Matplotlib, Excel, PowerPoint
# - **Machine Learning**: Statistical Modeling, Time Series Analysis, Time Series Modeling, Anomaly Detection
# - **Soft Skills**: Analytical Problem-Solving, Effective Communication, Leadership, Adaptability, Strategic Insight
# *Added*: - **Project Management & Collaboration Tools**: JIRA, Confluence, Slack
#
# ---
#
# **PROFESSIONAL EXPERIENCE**
#
# **Data Analyst II, Oracle Cerner**
# Jun 2020 - Present, Bengaluru
# - Leveraged Data Analytics with BI and SRE approaches to enhance healthcare customer experiences through real-time analytics and monitoring solutions, integrating statistical and predictive modeling. Key skills include SQL, Tableau, Python, and advanced statistical analysis.
# - *Drove a 20% improvement in operational efficiency by leading aftersales data analysis for 400+ clients, enhancing real-time abnormality detection and response strategies.*
# - *Implemented a predictive maintenance model for healthcare devices, reducing downtime by 30% and improving patient care.*
# - *Optimized data warehouse strategies, improving data retrieval times by 25% for critical analytics processes.*
# - *Facilitated cross-functional team collaboration to integrate BI solutions into the broader tech ecosystem, enhancing data interoperability and actionable insights.*
# - *Championed the adoption of a new BI toolset, leading to a 15% reduction in report generation times.*
# - Statistical Model Development: Designed and deployed models for performance monitoring across 400+ clients.
# - Cross-Client Performance Modeling: Created a model to assess client performance anomalies for prioritization.
# - Resource Utilization Model: Formulated a model for workload distribution, aiding in FTE and LOE estimations.
# - Data Processing Expertise: Employed advanced querying and visualization tools for complex data analysis.
# - Data Pipeline Management: Engineered data pipelines for efficient large-scale data collection and analysis.
# - KPI Interpretation and Visualization: Developed KPI-driven visualizations for business decision-making support.
# - Strategic Data Collaboration: Collaborated with leadership in implementing data-driven solutions and ad-hoc analysis.
#
# **Technical Consultant, Collins Aerospace**
# Feb 2019 - May 2020, Bengaluru, IN
# - Implemented a Power BI-based client help portal, significantly reducing issue response time.
# - Developed a predictive model for aircraft part maintenance, enhancing scheduling and reducing downtime.
# - Established a real-time tracking dashboard to enhance team efficiency and project management.
#
# **Process Associate, Capgemini**
# Apr 2017 - Feb 2019, Bengaluru
# - Conducted inventory stock analysis for Bombardier Aircrafts, recommending alternatives for unavailable parts.
# - Utilized data analysis for actionable insights into design modifications, parts lifecycle, and counterfeit risks.
#
# **Engineer, Aerodesign Solutions Pvt Ltd**
# Jul 2015 - Mar 2017, Bengaluru
# - Supported aviation market insights for successful project bids and developed bid optimization tools.
# - Enhanced pricing, timelines, and resource allocation strategies using historical data and client feedback.
#
# ---
#
# **EDUCATION**
# Master of Science in Data Science, Liverpool John Moores University
# Post Graduate Diploma in Data Science, IIIT Bangalore
# Bachelor of Technology in Aerospace, Hindustan Aviation Academy
#
# ---
#
# **CERTIFICATIONS**
# - Post Graduate Certification in Data Science, upGrad, January 2022
# - Data Analyst and Business Intelligence Certification, 365 Data Science Business Analyst, May 2021
# - Business Intelligence with SQL and Power BI, Simplilearn, March 2019
#
# ---
#
# *Note: The asterisk (*) denotes new or significantly revised content based on the suggestions for improvement. For the actual resume document, consider using formatting features like bold text or a different color to highlight these updates.*
